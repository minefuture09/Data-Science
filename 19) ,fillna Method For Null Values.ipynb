# %%
import pandas as pd

nba = pd.read_csv('nba.csv',index_col='Name')

nba.head()
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0

# %%
nba['Salary'].fillna(0,inplace=True)

# %%
nba['College'].fillna('No College',inplace=True)

# %%
nba.dropna(how='all',inplace=True)

# %%
nba.head()
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        0.0
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko         No College  5000000.0

# %%
nba.tail()
# Out:
#                    Team  Number Position   Age Height  Weight     College  \
# Name
# Trey Lyles    Utah Jazz    41.0       PF  20.0   6-10   234.0    Kentucky
# Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0      Butler
# Raul Neto     Utah Jazz    25.0       PG  24.0    6-1   179.0  No College
# Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0  No College
# Jeff Withey   Utah Jazz    24.0        C  26.0    7-0   231.0      Kansas
#
#                  Salary
# Name
# Trey Lyles    2239800.0
# Shelvin Mack  2433333.0
# Raul Neto      900000.0
# Tibor Pleiss  2900000.0
# Jeff Withey    947276.0
